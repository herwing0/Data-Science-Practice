# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
cars = pd.read_excel("C:/Users/alejandro/Desktop/Data Set.csv/cars.xls")

# %%
cars
# Out:
#             Price  Mileage    Make     Model           Trim   Type  Cylinder  \
# 0    17314.103129     8221   Buick   Century       Sedan 4D  Sedan         6
# 1    17542.036083     9135   Buick   Century       Sedan 4D  Sedan         6
# 2    16218.847862    13196   Buick   Century       Sedan 4D  Sedan         6
# 3    16336.913140    16342   Buick   Century       Sedan 4D  Sedan         6
# 4    16339.170324    19832   Buick   Century       Sedan 4D  Sedan         6
# 5    15709.052821    22236   Buick   Century       Sedan 4D  Sedan         6
# 6    15230.003390    22576   Buick   Century       Sedan 4D  Sedan         6
# 7    15048.042184    22964   Buick   Century       Sedan 4D  Sedan         6
# 8    14862.093870    24021   Buick   Century       Sedan 4D  Sedan         6
# 9    15295.018267    27325   Buick   Century       Sedan 4D  Sedan         6
# 10   21335.852485    10237   Buick  Lacrosse    CX Sedan 4D  Sedan         6
# ...

# %%
print("Minimum value :",cars["Price"].min())
# Out:
# Minimum value : 8638.930895260657

# %%
cars.sort_values("Price", ascending=False).iloc[0:10] # These are the most expensive Cars
# Out:
#             Price  Mileage      Make   Model             Trim         Type  \
# 150  70755.466717      583  Cadillac  XLR-V8  Hardtop Conv 2D  Convertible
# 152  69133.731722     7892  Cadillac  XLR-V8  Hardtop Conv 2D  Convertible
# 151  68566.187189     6420  Cadillac  XLR-V8  Hardtop Conv 2D  Convertible
# 153  66374.307040    12021  Cadillac  XLR-V8  Hardtop Conv 2D  Convertible
# 154  65281.481237    15600  Cadillac  XLR-V8  Hardtop Conv 2D  Convertible
# 155  63913.117248    18200  Cadillac  XLR-V8  Hardtop Conv 2D  Convertible
# 156  60567.549093    23193  Cadillac  XLR-V8  Hardtop Conv 2D  Convertible
# 157  57154.443437    29260  Cadillac  XLR-V8  Hardtop Conv 2D  Convertible
# 158  55639.087654    31805  Cadillac  XLR-V8  Hardtop Conv 2D  Convertible
# 159  52001.994379    42691  Cadillac  XLR-V8  Hardtop Conv 2D  Convertible
#
#      Cylinder  Liter  Doors  Cruise  Sound  Leather
# 150         8    4.6      2       1      1        1
# ...

# %%
cars[cars.Sound != 0] #We search for cars with sound system
# Out:
#             Price  Mileage    Make     Model             Trim   Type  \
# 0    17314.103129     8221   Buick   Century         Sedan 4D  Sedan
# 1    17542.036083     9135   Buick   Century         Sedan 4D  Sedan
# 2    16218.847862    13196   Buick   Century         Sedan 4D  Sedan
# 5    15709.052821    22236   Buick   Century         Sedan 4D  Sedan
# 6    15230.003390    22576   Buick   Century         Sedan 4D  Sedan
# 7    15048.042184    22964   Buick   Century         Sedan 4D  Sedan
# 9    15295.018267    27325   Buick   Century         Sedan 4D  Sedan
# 11   20538.087510    15066   Buick  Lacrosse      CX Sedan 4D  Sedan
# 12   20512.094091    16633   Buick  Lacrosse      CX Sedan 4D  Sedan
# 13   19924.159052    19800   Buick  Lacrosse      CX Sedan 4D  Sedan
# 14   19774.249066    23359   Buick  Lacrosse      CX Sedan 4D  Sedan
# 15   19344.165537    23765   Buick  Lacrosse      CX Sedan 4D  Sedan
# 17   18543.427045    26034   Buick  Lacrosse      CX Sedan 4D  Sedan
# ...

# %%
cars[(cars.Sound == 1) & (cars.Leather) == 1] # Now we search for the cars with sound system and leather seats
# Out:
#             Price  Mileage      Make        Model                 Trim   Type  \
# 0    17314.103129     8221     Buick      Century             Sedan 4D  Sedan
# 9    15295.018267    27325     Buick      Century             Sedan 4D  Sedan
# 13   19924.159052    19800     Buick     Lacrosse          CX Sedan 4D  Sedan
# 14   19774.249066    23359     Buick     Lacrosse          CX Sedan 4D  Sedan
# 17   18543.427045    26034     Buick     Lacrosse          CX Sedan 4D  Sedan
# 19   17968.838278    34665     Buick     Lacrosse          CX Sedan 4D  Sedan
# 21   23785.922526    10577     Buick     Lacrosse         CXL Sedan 4D  Sedan
# 22   22926.090371    14363     Buick     Lacrosse         CXL Sedan 4D  Sedan
# 28   21058.139580    24469     Buick     Lacrosse         CXL Sedan 4D  Sedan
# 32   23016.008009    18147     Buick     Lacrosse         CXS Sedan 4D  Sedan
# 36   21341.257207    25212     Buick     Lacrosse         CXS Sedan 4D  Sedan
# ...

# %%
sound_on = cars["Sound"] == 1 
leather_on = cars["Leather"] == 1

# %%
cars[sound_on & leather_on]
# Out:
#             Price  Mileage      Make        Model                 Trim   Type  \
# 0    17314.103129     8221     Buick      Century             Sedan 4D  Sedan
# 9    15295.018267    27325     Buick      Century             Sedan 4D  Sedan
# 13   19924.159052    19800     Buick     Lacrosse          CX Sedan 4D  Sedan
# 14   19774.249066    23359     Buick     Lacrosse          CX Sedan 4D  Sedan
# 17   18543.427045    26034     Buick     Lacrosse          CX Sedan 4D  Sedan
# 19   17968.838278    34665     Buick     Lacrosse          CX Sedan 4D  Sedan
# 21   23785.922526    10577     Buick     Lacrosse         CXL Sedan 4D  Sedan
# 22   22926.090371    14363     Buick     Lacrosse         CXL Sedan 4D  Sedan
# 28   21058.139580    24469     Buick     Lacrosse         CXL Sedan 4D  Sedan
# 32   23016.008009    18147     Buick     Lacrosse         CXS Sedan 4D  Sedan
# 36   21341.257207    25212     Buick     Lacrosse         CXS Sedan 4D  Sedan
# ...

# %%
variable1 = cars["Price"] <= 15000 
variable2 = cars["Sound"] == 1
variable3 = cars["Leather"] == 1
variable4 = cars["Mileage"] <= 15000
#We make some variables to search for specific cars

# %%
cars2 = cars[variable1 & variable2 & variable3 & variable4] # We create a new dataset with only this variables
cars2
# Out:
#             Price  Mileage       Make     Model               Trim       Type  \
# 172  11318.008089    11156  Chevrolet      AVEO        LS Sedan 4D      Sedan
# 173  12409.949094    11981  Chevrolet      AVEO        LS Sedan 4D      Sedan
# 202  10897.076506     6699  Chevrolet      AVEO   SVM Hatchback 4D  Hatchback
# 220  13007.984178     7372  Chevrolet  Cavalier           Coupe 2D      Coupe
# 221  13041.873997    13607  Chevrolet  Cavalier           Coupe 2D      Coupe
# 230  14584.448122     1160  Chevrolet  Cavalier        LS Coupe 2D      Coupe
# 231  13681.698003    10210  Chevrolet  Cavalier        LS Coupe 2D      Coupe
# 240  14894.982593     2464  Chevrolet  Cavalier        LS Sedan 4D      Sedan
# 241  14198.092459    11322  Chevrolet  Cavalier        LS Sedan 4D      Sedan
# 242  14678.105334    11488  Chevrolet  Cavalier        LS Sedan 4D      Sedan
# 243  13167.702321    14630  Chevrolet  Cavalier        LS Sedan 4D      Sedan
# ...

# %%
cars2.sort_values("Price", ascending=True).iloc[0:5] # We search for the most low price cars with this specific values
# Out:
#             Price  Mileage       Make     Model              Trim       Type  \
# 202  10897.076506     6699  Chevrolet      AVEO  SVM Hatchback 4D  Hatchback
# 172  11318.008089    11156  Chevrolet      AVEO       LS Sedan 4D      Sedan
# 173  12409.949094    11981  Chevrolet      AVEO       LS Sedan 4D      Sedan
# 220  13007.984178     7372  Chevrolet  Cavalier          Coupe 2D      Coupe
# 221  13041.873997    13607  Chevrolet  Cavalier          Coupe 2D      Coupe
#
#      Cylinder  Liter  Doors  Cruise  Sound  Leather
# 202         4    1.6      4       0      1        1
# 172         4    1.6      4       0      1        1
# 173         4    1.6      4       1      1        1
# 220         4    2.2      2       1      1        1
# 221         4    2.2      2       0      1        1
